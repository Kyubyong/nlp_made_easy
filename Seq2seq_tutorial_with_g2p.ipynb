# %%
import numpy as np
import tensorflow as tf
# tf.enable_eager_execution()

# %%
tf.__version__
# Out:
# '1.13.0-rc0'

# %% [markdown]
# # Hyperparameters

# %%
params = dict()
params["batch_size"] = 16
params["maxlen"] = 100
params["num_epochs"] = 10
params["hidden_units"] = 32
params["graphemes"] = ["<PAD>", "<UNK>", "<BOS>", "<EOS>"] + list("abcdefghijklmnopqrstuvwxyz")
params["phonemes"] = ["<PAD>", "<UNK>", "<BOS>", "<EOS>"] + ['AA0', 'AA1', 'AA2', 'AE0', 'AE1', 'AE2', 'AH0', 'AH1', 'AH2', 'AO0',
                'AO1', 'AO2', 'AW0', 'AW1', 'AW2', 'AY0', 'AY1', 'AY2', 'B', 'CH', 'D', 'DH',
                'EH0', 'EH1', 'EH2', 'ER0', 'ER1', 'ER2', 'EY0', 'EY1', 'EY2', 'F', 'G', 'HH',
                'IH0', 'IH1', 'IH2', 'IY0', 'IY1', 'IY2', 'JH', 'K', 'L', 'M', 'N', 'NG', 'OW0', 'OW1',
                'OW2', 'OY0', 'OY1', 'OY2', 'P', 'R', 'S', 'SH', 'T', 'TH', 'UH0', 'UH1', 'UH2', 'UW',
                'UW0', 'UW1', 'UW2', 'V', 'W', 'Y', 'Z', 'ZH']
params["lr"] = 0.001
params["eval_steps"] = 100

# %% [markdown]
# # Prepare Data

# %%
import nltk
# nltk.download('cmudict')
from nltk.corpus import cmudict
cmu = cmudict.dict()

# %%
def load_vocab():
    g2idx = {g: idx for idx, g in enumerate(params["graphemes"])}
    idx2g = {idx: g for idx, g in enumerate(params["graphemes"])}

    p2idx = {p: idx for idx, p in enumerate(params["phonemes"])}
    idx2p = {idx: p for idx, p in enumerate(params["phonemes"])}

    return g2idx, idx2g, p2idx, idx2p

# %%
def prepare_data():
    words = [word for word, prons in cmu.items()]
    prons = [" ".join(prons[0]) for word, prons in cmu.items()]
    indices = list(range(len(words)))
    from random import shuffle
    shuffle(indices)
    words = [words[idx] for idx in indices]
    prons = [prons[idx] for idx in indices]
    num_train, num_test = int(len(words)*.8), int(len(words)*.1)
    train_words, eval_words, test_words = words[:num_train], \
                                          words[num_train:-num_test],\
                                          words[-num_test:]
    train_prons, eval_prons, test_prons = prons[:num_train], \
                                          prons[num_train:-num_test],\
                                          prons[-num_test:]    
    return train_words, eval_words, test_words, train_prons, eval_prons, test_prons

# %%
train_words, eval_words, test_words, train_prons, eval_prons, test_prons = prepare_data()

# %% [markdown]
# # Data Loader

# %%
def generator_fn(words, prons, maxlen):
  '''
  words: list of words. e.g., ["word", ]
  prons: list of prons. e.g., ['W ER1 D',]
  maxlen: scalar.
  '''
  g2idx, idx2g, p2idx, idx2p = load_vocab()
    
  for word, pron in zip(words, prons):
      graphemes = list(word.decode('utf-8')) + ["<EOS>"]
      phonemes = pron.decode('utf-8').split() + ["<EOS>"]
      if max(len(graphemes), len(phonemes)) > maxlen: continue

      x = [g2idx.get(g, g2idx["<UNK>"]) for g in graphemes]
      y = [p2idx.get(p, p2idx["<UNK>"]) for p in phonemes]

      yield (x, len(x), word), (y, len(y), pron)

# %%
def input_fn(words, prons, maxlen, batch_size, shuffle=True, num_repeat=1):
    '''Batchify data
    words: list of words. e.g., ["word", ]
    prons: list of prons. e.g., ['W ER1 D',]
    maxlen: scalar.
    batch_size: scalar.
    shuffle: boolean
    num_repeat: int.
    '''
    shapes = (  ([None], (), ()),
                ([None], (), ())    )
    types = (   (tf.int32, tf.int32, tf.string),
                (tf.int32, tf.int32, tf.string)    )
    paddings = (    (0, 0, ''),
                    (0, 0, '')     )

    dataset = tf.data.Dataset.from_generator(
        generator_fn,
        output_shapes=shapes,
        output_types=types,
        args=(words, prons, maxlen))
        
    if shuffle:
        dataset = dataset.shuffle(64*batch_size)

    dataset = dataset.repeat(num_repeat)
    dataset = dataset.padded_batch(batch_size, shapes, paddings).prefetch(1)

    return dataset

# %% [markdown]
# # Model

# %%
tf.reset_default_graph()
class Model:
    def __init__(self, params):
        self.g2idx, self.idx2g, self.p2idx, self.idx2p = load_vocab()
        self.params = params
    
    def encode(self, xs):
        '''
        xs: tupple of 
            x: (N, T)
            seqlens: (N,)
            sent: (N,)
            
        returns last hidden state of shape (N, hidden_units)    
        '''
        with tf.variable_scope("encode"):
            x, seqlens, words = xs
            x = tf.one_hot(x, len(self.g2idx))
            cell = tf.contrib.rnn.GRUCell(self.params["hidden_units"])
            outputs, last_hidden = tf.nn.dynamic_rnn(cell, x, seqlens, dtype=tf.float32)
        
        return last_hidden, words
        
    
    def decode(self, ys, h0=None):
        '''
        ys: tupple of 
            y: (N, T)
            seqlens: (N,)
            sent: (N,)
            
        returns last hidden state of shape (N, hidden_units)  
        '''
        y, seqlens, prons = ys
        
        # decoder inputs <- shifted right
        inputs = tf.concat(  (tf.ones_like(y[:, :1])*self.p2idx["<BOS>"], y[:, :-1]),  -1   )
            
        with tf.variable_scope("decode"):
            inputs = tf.one_hot(inputs, len(self.p2idx))
            cell = tf.contrib.rnn.GRUCell(self.params["hidden_units"])
            outputs, _ = tf.nn.dynamic_rnn(cell, inputs, initial_state=h0, dtype=tf.float32)

            # projection
            logits = tf.layers.dense(outputs, len(self.p2idx))
            preds = tf.to_int32(tf.argmax(logits, axis=-1))
        
        return logits, preds, y, prons
        
    
    def forward(self, xs, ys):
        last_hidden, word = self.encode(xs)
        logits, preds, y, prons = self.decode(ys, h0=last_hidden)
        return word, logits, preds, y, prons

# %% [markdown]
# # Train & Evaluate

# %%
train_batches = input_fn(train_words, train_prons, params["maxlen"], params["batch_size"], \
                                                          shuffle=True, num_repeat=params["num_epochs"])
eval_batches = input_fn(eval_words, eval_prons, params["maxlen"], params["batch_size"], \
                                                          shuffle=False, num_repeat=1)

# %%
# create a iterator of the correct shape and type
iter = tf.data.Iterator.from_structure(train_batches.output_types, eval_batches.output_shapes)
xs, ys = iter.get_next()

# create the initialisation operations
train_init_op = iter.make_initializer(train_batches)
eval_init_op = iter.make_initializer(eval_batches)

# %%
m = Model(params)
words, logits, preds, y, prons = m.forward(xs, ys)

# train
ce = tf.nn.sparse_softmax_cross_entropy_with_logits(logits=logits, labels=y)
mask = tf.to_float(tf.not_equal(y, m.p2idx["<PAD>"])) # 0: <pad>
loss = tf.reduce_sum(ce*mask) / (tf.reduce_sum(mask)+1e-7)

global_step = tf.train.get_or_create_global_step()
train_op = tf.train.AdamOptimizer(params["lr"]).minimize(loss, global_step=global_step)
# Out:
# WARNING:tensorflow:From <ipython-input-31-e560bc48303f>:45: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# WARNING:tensorflow:From <ipython-input-34-e828fb837d78>:6: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %%
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    sess.run(train_init_op)
    
    sv = tf.train.Saver()
    sv.saver.save(sess, hp.logdir + '/model_epoch_%02d_gs_%d' % (epoch, gs))
    
    while True:
        try:
            # training
            _, _gs = sess.run([train_op, global_step])
            
            
            # evaluation
            if _gs%params["eval_steps"]==0:
                _loss = sess.run(loss)
                print("="*10, "global step=", _gs, "="*10)
                print("train loss= %.2f" % _loss)
                
                sess.run(eval_init_op)
                _words, _preds, _prons = sess.run([words, preds, prons])
                
                ## logging
                _w = _words[0].decode('utf-8')
                _gt = _prons[0].decode('utf-8')
                _p = " ".join(m.idx2p[each] for each in _preds[0]).split("<EOS>")[0]
                print("input:", _w)
                print("expected:", _gt)
                print("got:", _p)
                print()
            
        except tf.errors.OutOfRangeError: break
# Out:
# ========== global step= 100 ==========
# train loss= 3.54
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: R
#
# ========== global step= 200 ==========
# train loss= 3.26
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: R L L AH0
#
# ========== global step= 300 ==========
# train loss= 3.18
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: R L AH0 AH0
#
# ========== global step= 400 ==========
# train loss= 3.14
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: R L AH0 AH0
#
# ========== global step= 500 ==========
# train loss= 3.09
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: R L L AH0
#
# ========== global step= 600 ==========
# train loss= 3.04
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: R L N AH0 N
#
# ========== global step= 700 ==========
# train loss= 2.99
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: S AH0 L AH0 N
#
# ========== global step= 800 ==========
# train loss= 2.95
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: K AH0 L AH0 N
#
# ========== global step= 900 ==========
# train loss= 2.91
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: B AE1 L AH0 N
#
# ========== global step= 1000 ==========
# train loss= 2.87
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: B AE1 L AH0 N
#
# ========== global step= 1100 ==========
# train loss= 2.83
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: B AE1 L AH0 N
#
# ========== global step= 1200 ==========
# train loss= 2.79
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: B AE1 L AH0 N
#
# ========== global step= 1300 ==========
# train loss= 2.75
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: B AE1 L AH0 N
#
# ========== global step= 1400 ==========
# train loss= 2.72
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: B IH1 L AH0 N
#
# ========== global step= 1500 ==========
# train loss= 2.69
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: B IH1 L AH0 N
#
# ========== global step= 1600 ==========
# train loss= 2.67
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: B IH1 L AH0 N
#
# ========== global step= 1700 ==========
# train loss= 2.65
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: B IH1 L AH0 N
#
# ========== global step= 1800 ==========
# train loss= 2.63
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: B IH1 L AH0 NG
#
# ========== global step= 1900 ==========
# train loss= 2.61
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: B IH1 L AH0 NG
#
# ========== global step= 2000 ==========
# train loss= 2.59
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: B IH1 L AH0 NG
#
# ========== global step= 2100 ==========
# train loss= 2.57
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: B IH1 L AH0 NG
#
# ========== global step= 2200 ==========
# train loss= 2.55
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: B IH1 S AH0 NG
#
# ========== global step= 2300 ==========
# train loss= 2.53
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: B IH1 S AH0 NG
#
# ========== global step= 2400 ==========
# train loss= 2.52
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: B IH1 S AH0 NG
#
# ========== global step= 2500 ==========
# train loss= 2.50
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: B IH1 S AH0 NG
#
# ========== global step= 2600 ==========
# train loss= 2.49
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: B IH1 N AH0 NG
#
# ========== global step= 2700 ==========
# train loss= 2.47
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: B IH1 N AH0 NG
#
# ========== global step= 2800 ==========
# train loss= 2.46
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: B IH1 N AH0 NG
#
# ========== global step= 2900 ==========
# train loss= 2.45
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: B IH1 N AH0 NG
#
# ========== global step= 3000 ==========
# train loss= 2.44
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: B IH1 N AH0 NG
#
# ========== global step= 3100 ==========
# train loss= 2.43
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: B IH1 N AH0 NG
#
# ========== global step= 3200 ==========
# train loss= 2.42
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: B IH1 N AH0 NG
#
# ========== global step= 3300 ==========
# train loss= 2.40
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: B IH1 N IH0 NG
#
# ========== global step= 3400 ==========
# train loss= 2.39
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: B IH1 N IH0 NG
#
# ========== global step= 3500 ==========
# train loss= 2.37
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 N IH0 NG
#
# ========== global step= 3600 ==========
# train loss= 2.36
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 N IH0 NG
#
# ========== global step= 3700 ==========
# train loss= 2.34
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 N IH0 NG
#
# ========== global step= 3800 ==========
# train loss= 2.33
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 N IH0 NG
#
# ========== global step= 3900 ==========
# train loss= 2.31
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 N IH0 N
#
# ========== global step= 4000 ==========
# train loss= 2.30
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 N IH0 N
#
# ========== global step= 4100 ==========
# train loss= 2.28
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 N IH0 N
#
# ========== global step= 4200 ==========
# train loss= 2.25
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 N IH0 N
#
# ========== global step= 4300 ==========
# train loss= 2.22
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 N IH0 N
#
# ========== global step= 4400 ==========
# train loss= 2.20
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 N IH0 N
#
# ========== global step= 4500 ==========
# train loss= 2.18
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 N IH0 N
#
# ========== global step= 4600 ==========
# train loss= 2.17
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 N IH0 N
#
# ========== global step= 4700 ==========
# train loss= 2.16
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 N IH0 N
#
# ========== global step= 4800 ==========
# train loss= 2.15
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 N IH0 N
#
# ========== global step= 4900 ==========
# train loss= 2.14
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 N IH0 N
#
# ========== global step= 5000 ==========
# train loss= 2.14
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 N IH0 N
#
# ========== global step= 5100 ==========
# train loss= 2.14
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 N IH0 N
#
# ========== global step= 5200 ==========
# train loss= 2.13
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 N IH0 N
#
# ========== global step= 5300 ==========
# train loss= 2.13
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 N IH0 N
#
# ========== global step= 5400 ==========
# train loss= 2.13
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 N IH0 N
#
# ========== global step= 5500 ==========
# train loss= 2.12
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 N IH0 N
#
# ========== global step= 5600 ==========
# train loss= 2.12
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 N IH0 N
#
# ========== global step= 5700 ==========
# train loss= 2.11
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 N IH0 N
#
# ========== global step= 5800 ==========
# train loss= 2.11
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 N IH0 N
#
# ========== global step= 5900 ==========
# train loss= 2.10
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 N IH0 N
#
# ========== global step= 6000 ==========
# train loss= 2.10
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 N IH0 NG
#
# ========== global step= 6100 ==========
# train loss= 2.10
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 N IH0 NG
#
# ========== global step= 6200 ==========
# train loss= 2.09
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 N IH0 NG
#
# ========== global step= 6300 ==========
# train loss= 2.08
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 N IH0 NG
#
# ========== global step= 6400 ==========
# train loss= 2.06
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 N IH0 NG
#
# ========== global step= 6500 ==========
# train loss= 2.04
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 N IH0 NG
#
# ========== global step= 6600 ==========
# train loss= 2.03
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 D IH0 NG Z
#
# ========== global step= 6700 ==========
# train loss= 2.01
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 D IH0 NG Z
#
# ========== global step= 6800 ==========
# train loss= 2.03
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 D IH0 NG Z
#
# ========== global step= 6900 ==========
# train loss= 2.02
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 D IH0 NG Z
#
# ========== global step= 7000 ==========
# train loss= 1.98
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 D IH0 NG Z
#
# ========== global step= 7100 ==========
# train loss= 1.97
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 D IH0 NG Z
#
# ========== global step= 7200 ==========
# train loss= 1.94
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 D IH0 NG Z
#
# ========== global step= 7300 ==========
# train loss= 1.93
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 D IH0 NG Z
#
# ========== global step= 7400 ==========
# train loss= 1.93
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 D IH0 NG Z
#
# ========== global step= 7500 ==========
# train loss= 1.94
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 D IH0 NG Z
#
# ========== global step= 7600 ==========
# train loss= 1.95
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 D IH0 NG Z
#
# ========== global step= 7700 ==========
# train loss= 1.95
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 D IH0 NG Z
#
# ========== global step= 7800 ==========
# train loss= 1.95
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 D IH0 NG Z
#
# ========== global step= 7900 ==========
# train loss= 1.95
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 D IH0 NG Z
#
# ========== global step= 8000 ==========
# train loss= 1.94
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 S IH0 NG Z
#
# ========== global step= 8100 ==========
# train loss= 1.93
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 S IH0 NG Z
#
# ========== global step= 8200 ==========
# train loss= 1.88
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 S IH0 NG Z
#
# ========== global step= 8300 ==========
# train loss= 1.86
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 S IH0 NG Z
#
# ========== global step= 8400 ==========
# train loss= 1.87
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 S IH0 NG
#
# ========== global step= 8500 ==========
# train loss= 1.87
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 S IH0 NG
#
# ========== global step= 8600 ==========
# train loss= 1.89
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 S IH0 NG
#
# ========== global step= 8700 ==========
# train loss= 1.89
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 S IH0 NG
#
# ========== global step= 8800 ==========
# train loss= 1.92
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 S IH0 NG
#
# ========== global step= 8900 ==========
# train loss= 1.89
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 S IH0 NG
#
# ========== global step= 9000 ==========
# train loss= 1.94
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 S IH0 NG Z
#
# ========== global step= 9100 ==========
# train loss= 1.90
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 S IH0 NG Z
#
# ========== global step= 9200 ==========
# train loss= 1.93
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 S IH0 NG Z
#
# ========== global step= 9300 ==========
# train loss= 1.91
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 S IH0 NG Z
#
# ========== global step= 9400 ==========
# train loss= 1.98
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 S IH0 NG Z
#
# ========== global step= 9500 ==========
# train loss= 1.92
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 S IH0 NG Z
#
# ========== global step= 9600 ==========
# train loss= 1.96
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 S IH0 NG Z
#
# ========== global step= 9700 ==========
# train loss= 1.94
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 S IH0 NG Z
#
# ========== global step= 9800 ==========
# train loss= 1.97
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 S IH0 NG Z
#
# ========== global step= 9900 ==========
# train loss= 1.93
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 S IH0 NG Z
#
# ========== global step= 10000 ==========
# train loss= 1.96
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 S IH0 NG Z
#
# ========== global step= 10100 ==========
# train loss= 1.94
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 S IH0 NG Z
#
# ========== global step= 10200 ==========
# train loss= 2.00
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 S IH0 NG Z
#
# ========== global step= 10300 ==========
# train loss= 1.95
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 S IH0 NG Z
#
# ========== global step= 10400 ==========
# train loss= 1.97
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 S IH0 NG Z
#
# ========== global step= 10500 ==========
# train loss= 1.96
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 S IH0 NG Z
#
# ========== global step= 10600 ==========
# train loss= 1.96
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 S IH0 NG Z
#
# ========== global step= 10700 ==========
# train loss= 1.97
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 S IH0 NG Z
#
# ========== global step= 10800 ==========
# train loss= 1.95
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 S IH0 NG Z
#
# ========== global step= 10900 ==========
# train loss= 1.94
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 S IH0 NG Z
#
# ========== global step= 11000 ==========
# train loss= 1.94
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 S IH0 NG Z
#
# ========== global step= 11100 ==========
# train loss= 1.94
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 S IH0 NG Z
#
# ========== global step= 11200 ==========
# train loss= 1.90
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 S IH0 NG Z
#
# ========== global step= 11300 ==========
# train loss= 1.93
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 S IH0 NG Z
#
# ========== global step= 11400 ==========
# train loss= 1.90
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 S IH0 NG Z
#
# ========== global step= 11500 ==========
# train loss= 1.91
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 S IH0 NG Z
#
# ========== global step= 11600 ==========
# train loss= 1.94
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 S IH0 NG Z
#
# ========== global step= 11700 ==========
# train loss= 1.89
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 S IH0 NG Z
#
# ========== global step= 11800 ==========
# train loss= 1.90
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 S IH0 NG Z
#
# ========== global step= 11900 ==========
# train loss= 1.90
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 S IH0 NG Z
#
# ========== global step= 12000 ==========
# train loss= 1.91
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 S IH0 NG Z
#
# ========== global step= 12100 ==========
# train loss= 1.91
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 S IH0 NG Z
#
# ========== global step= 12200 ==========
# train loss= 1.94
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 S IH0 NG Z
#
# ========== global step= 12300 ==========
# train loss= 1.95
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 S AY2 NG Z
#
# ========== global step= 12400 ==========
# train loss= 1.91
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 Z AY2 NG Z
#
# ========== global step= 12500 ==========
# train loss= 1.91
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 S AY2 NG Z
#
# ========== global step= 12600 ==========
# train loss= 1.89
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH0 S AY2 NG Z
#
# ========== global step= 12700 ==========
# train loss= 1.93
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH0 S AY2 NG Z
#
# ========== global step= 12800 ==========
# train loss= 1.91
# input: tydings
# expected: T AY1 D IH0 NG Z
# got: T IH1 S AY2 NG Z
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-35-818dd9e0f98b> in <module>()
#       6         try:
#       7             # training
# ----> 8             _, _gs = sess.run([train_op, global_step])
#       9
#      10
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     927     try:
#     928       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 929                          run_metadata_ptr)
#     930       if run_metadata:
#     931         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1150     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1151       results = self._do_run(handle, final_targets, final_fetches,
# -> 1152                              feed_dict_tensor, options, run_metadata)
#    1153     else:
#    1154       results = []
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1326     if handle is None:
#    1327       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1328                            run_metadata)
#    1329     else:
#    1330       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1332   def _do_call(self, fn, *args):
#    1333     try:
# -> 1334       return fn(*args)
#    1335     except errors.OpError as e:
#    1336       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1317       self._extend_graph()
#    1318       return self._call_tf_sessionrun(
# -> 1319           options, feed_dict, fetch_list, target_list, run_metadata)
#    1320
#    1321     def _prun_fn(handle, feed_dict, fetch_list):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1405     return tf_session.TF_SessionRun_wrapper(
#    1406         self._session, options, feed_dict, fetch_list, target_list,
# -> 1407         run_metadata)
#    1408
#    1409   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# # Inference

# %%
tf.reset_default_graph()

# %%
test_batches = input_fn(test_words, "", params["maxlen"], params["batch_size"], \
                                                          shuffle=False, num_repeat=1)

# %%
# create a iterator of the correct shape and type
iter = tf.data.Iterator.from_structure(test_batches.output_types, test_batches.output_shapes)
xs, ys = iter.get_next()

# create the initialisation operations
test_init_op = iter.make_initializer(test_batches)

# %%
# Out:
# (<tf.Tensor 'IteratorGetNext:0' shape=(?, ?) dtype=int32>,
#  <tf.Tensor 'IteratorGetNext:1' shape=(?,) dtype=int32>,
#  <tf.Tensor 'IteratorGetNext:2' shape=(?,) dtype=string>)

# %%
m = Model(params)
last_hidden, words = m.encode(xs)

preds = tf.fill((tf.shape(last_hidden)[0], 1), m.p2idx["<BOS>"])
for t in range(params["maxlen"]):
    logits, _preds, _, _ = m.decode(preds, h0=last_hidden, mode="infer")
    preds = _preds
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-12d5d59b25f7> in <module>
#       4 inputs = tf.fill((tf.shape(last_hidden)[0], 1), m.p2idx["<BOS>"])
#       5 for t in range(params["maxlen"]):
# ----> 6     logits, preds, _, _ = m.decode(inputs, h0=last_hidden, mode="infer")
#       7
#       8     inputs = tf.concat(  (tf.ones_like(preds[:, :1])*m.p2idx["<BOS>"], preds[:, :-1]),  -1   )  # shifted right
#
# <ipython-input-11-b0c029ca6eb3> in decode(self, ys, h0, mode)
#      42             inputs = tf.one_hot(inputs, len(self.p2idx))
#      43             cell = tf.contrib.rnn.GRUCell(self.params["hidden_units"])
# ---> 44             outputs, _ = tf.nn.dynamic_rnn(cell, inputs, initial_state=h0, dtype=tf.float32)
#      45
#      46             # projection
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/rnn.py in dynamic_rnn(cell, inputs, sequence_length, initial_state, dtype, parallel_iterations, swap_memory, time_major, scope)
#     662         swap_memory=swap_memory,
#     663         sequence_length=sequence_length,
# --> 664         dtype=dtype)
#     665
#     666     # Outputs of _dynamic_rnn_loop are always shaped [time, batch, depth].
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/rnn.py in _dynamic_rnn_loop(cell, inputs, initial_state, parallel_iterations, swap_memory, sequence_length, dtype)
#     870       parallel_iterations=parallel_iterations,
#     871       maximum_iterations=time_steps,
# --> 872       swap_memory=swap_memory)
#     873
#     874   # Unpack final output if not using output tuples.
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/control_flow_ops.py in while_loop(cond, body, loop_vars, shape_invariants, parallel_iterations, back_prop, swap_memory, name, maximum_iterations, return_same_structure)
#    3289       ops.add_to_collection(ops.GraphKeys.WHILE_CONTEXT, loop_context)
#    3290     result = loop_context.BuildLoop(cond, body, loop_vars, shape_invariants,
# -> 3291                                     return_same_structure)
#    3292     if maximum_iterations is not None:
#    3293       return result[1]
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/control_flow_ops.py in BuildLoop(self, pred, body, loop_vars, shape_invariants, return_same_structure)
#    3002       with ops.get_default_graph()._mutation_lock():  # pylint: disable=protected-access
#    3003         original_body_result, exit_vars = self._BuildLoop(
# -> 3004             pred, body, original_loop_vars, loop_vars, shape_invariants)
#    3005     finally:
#    3006       self.Exit()
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/control_flow_ops.py in _BuildLoop(self, pred, body, original_loop_vars, loop_vars, shape_invariants)
#    2937         flat_sequence=vars_for_body_with_tensor_arrays)
#    2938     pre_summaries = ops.get_collection(ops.GraphKeys._SUMMARY_COLLECTION)  # pylint: disable=protected-access
# -> 2939     body_result = body(*packed_vars_for_body)
#    2940     post_summaries = ops.get_collection(ops.GraphKeys._SUMMARY_COLLECTION)  # pylint: disable=protected-access
#    2941     if not nest.is_sequence(body_result):
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/control_flow_ops.py in <lambda>(i, lv)
#    3258         cond = lambda i, lv: (  # pylint: disable=g-long-lambda
#    3259             math_ops.logical_and(i < maximum_iterations, orig_cond(*lv)))
# -> 3260         body = lambda i, lv: (i + 1, orig_body(*lv))
#    3261
#    3262     if context.executing_eagerly():
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/rnn.py in _time_step(time, output_ta_t, state)
#     838           skip_conditionals=True)
#     839     else:
# --> 840       (output, new_state) = call_cell()
#     841
#     842     # Keras cells always wrap state as list, even if it's a single tensor.
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/rnn.py in <lambda>()
#     824     if is_keras_rnn_cell and not nest.is_sequence(state):
#     825       state = [state]
# --> 826     call_cell = lambda: cell(input_t, state)
#     827
#     828     if sequence_length is not None:
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/rnn_cell_impl.py in __call__(self, inputs, state, scope, *args, **kwargs)
#     368     # method.  See the class docstring for more details.
#     369     return base_layer.Layer.__call__(self, inputs, state, scope=scope,
# --> 370                                      *args, **kwargs)
#     371
#     372
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/layers/base.py in __call__(self, inputs, *args, **kwargs)
#     372
#     373       # Actually call layer
# --> 374       outputs = super(Layer, self).__call__(inputs, *args, **kwargs)
#     375
#     376     if not context.executing_eagerly():
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/keras/engine/base_layer.py in __call__(self, inputs, *args, **kwargs)
#     744           # the user has manually overwritten the build method do we need to
#     745           # build it.
# --> 746           self.build(input_shapes)
#     747         # We must set self.built since user defined build functions are not
#     748         # constrained to set self.built.
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/keras/utils/tf_utils.py in wrapper(instance, input_shape)
#     147       else:
#     148         input_shape = tuple(tensor_shape.TensorShape(input_shape).as_list())
# --> 149     output_shape = fn(instance, input_shape)
#     150     if output_shape is not None:
#     151       if isinstance(output_shape, list):
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/rnn_cell_impl.py in build(self, inputs_shape)
#     534         "gates/%s" % _WEIGHTS_VARIABLE_NAME,
#     535         shape=[input_depth + self._num_units, 2 * self._num_units],
# --> 536         initializer=self._kernel_initializer)
#     537     self._gate_bias = self.add_variable(
#     538         "gates/%s" % _BIAS_VARIABLE_NAME,
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/keras/engine/base_layer.py in add_variable(self, *args, **kwargs)
#     493   def add_variable(self, *args, **kwargs):
#     494     """Alias for `add_weight`."""
# --> 495     return self.add_weight(*args, **kwargs)
#     496
#     497   @doc_controls.for_subclass_implementers
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/layers/base.py in add_weight(self, name, shape, dtype, initializer, regularizer, trainable, constraint, use_resource, synchronization, aggregation, partitioner)
#     286             synchronization=synchronization,
#     287             aggregation=aggregation,
# --> 288             getter=vs.get_variable)
#     289
#     290         if regularizer:
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/keras/engine/base_layer.py in add_weight(self, name, shape, dtype, initializer, regularizer, trainable, constraint, partitioner, use_resource, synchronization, aggregation, **kwargs)
#     607         collections=collections,
#     608         synchronization=synchronization,
# --> 609         aggregation=aggregation)
#     610     backend.track_variable(variable)
#     611
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/checkpointable/base.py in _add_variable_with_custom_getter(self, name, shape, dtype, initializer, getter, overwrite, **kwargs_for_getter)
#     637     new_variable = getter(
#     638         name=name, shape=shape, dtype=dtype, initializer=initializer,
# --> 639         **kwargs_for_getter)
#     640
#     641     # If we set an initializer and the variable processed it, tracking will not
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/variable_scope.py in get_variable(name, shape, dtype, initializer, regularizer, trainable, collections, caching_device, partitioner, validate_shape, use_resource, custom_getter, constraint, synchronization, aggregation)
#    1485       constraint=constraint,
#    1486       synchronization=synchronization,
# -> 1487       aggregation=aggregation)
#    1488
#    1489
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/variable_scope.py in get_variable(self, var_store, name, shape, dtype, initializer, regularizer, reuse, trainable, collections, caching_device, partitioner, validate_shape, use_resource, custom_getter, constraint, synchronization, aggregation)
#    1235           constraint=constraint,
#    1236           synchronization=synchronization,
# -> 1237           aggregation=aggregation)
#    1238
#    1239   def _get_partitioned_variable(self,
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/variable_scope.py in get_variable(self, name, shape, dtype, initializer, regularizer, reuse, trainable, collections, caching_device, partitioner, validate_shape, use_resource, custom_getter, constraint, synchronization, aggregation)
#     538           constraint=constraint,
#     539           synchronization=synchronization,
# --> 540           aggregation=aggregation)
#     541
#     542   def _get_partitioned_variable(self,
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/variable_scope.py in _true_getter(name, shape, dtype, initializer, regularizer, reuse, trainable, collections, caching_device, partitioner, validate_shape, use_resource, constraint, synchronization, aggregation)
#     490           constraint=constraint,
#     491           synchronization=synchronization,
# --> 492           aggregation=aggregation)
#     493
#     494     # Set trainable value based on synchronization value.
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/variable_scope.py in _get_single_variable(self, name, shape, dtype, initializer, regularizer, partition_info, reuse, trainable, collections, caching_device, validate_shape, use_resource, constraint, synchronization, aggregation)
#     859                          "reuse=tf.AUTO_REUSE in VarScope? "
#     860                          "Originally defined at:\n\n%s" % (
# --> 861                              name, "".join(traceback.format_list(tb))))
#     862       found_var = self._vars[name]
#     863       if not shape.is_compatible_with(found_var.get_shape()):
#
# ValueError: Variable decode/rnn/gru_cell/gates/kernel already exists, disallowed. Did you mean to set reuse=True or reuse=tf.AUTO_REUSE in VarScope? Originally defined at:
#
#   File "<ipython-input-11-b0c029ca6eb3>", line 44, in decode
#     outputs, _ = tf.nn.dynamic_rnn(cell, inputs, initial_state=h0, dtype=tf.float32)
#   File "<ipython-input-15-12d5d59b25f7>", line 6, in <module>
#     logits, preds, _, _ = m.decode(inputs, h0=last_hidden, mode="infer")
#   File "/usr/local/lib/python3.5/dist-packages/IPython/core/interactiveshell.py", line 3267, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)

# %%
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    sess.run(test_init_op)
    
    while True:
        try:
            # training
            _preds = sess.run([preds])
